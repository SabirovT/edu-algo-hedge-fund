# %%
import numpy as np
import pandas as pd

# %%
years = [2017, 2018, 2019, 2020, 2021]
companies = ['AAPL', 'MSFT', 'AMZN', 'TSLA', 'GOOGL', 'GOOG', 'BRK.B', 'UNH', 'JNJ', 'XOM']
data = {}
for company in companies:
    df = pd.DataFrame()
    for year in range(2017, 2022):
        try: 
            tmp_df = pd.read_csv('data/'+str(year)+'/'+company+'.csv')
            df = pd.concat([df, tmp_df])
        except: continue
    data[company] = df
    print(company)
# Out:
# AAPL
# MSFT
# AMZN
# TSLA
# GOOGL
# GOOG
# BRK.B
# UNH
# JNJ
# XOM

# %%
for company in companies:
    data[company].plot('timestamp', 'close')
    print(len(data[company]))
# Out:
# 404437
# 404322
# 403604
# 404240
# 393839
# 394028
# 403246
# 403242
# 404013
# 403903
